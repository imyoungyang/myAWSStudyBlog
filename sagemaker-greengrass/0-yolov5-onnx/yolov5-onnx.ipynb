# %% [markdown]
# # Convert YoloV5 to ONNX on SageMaker Notebook Instance
#
# The official document is [here](https://github.com/ultralytics/yolov5/issues/251). Here is demostration how to use SageMaker jupyter notebook to export YoloV5 model to ONNX.

# %%
# !pip install tensorboard onnx torch --upgrade

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# Add yolov5 system path
import sys, os, onnx, torch

# %%
print('\nStarting TorchScript export with torch %s...' % torch.__version__)
# Out:
# Starting TorchScript export with torch 1.5.1...

# %%
fp_yolov5 = os.path.abspath(os.getcwd()) + "/yolov5"
fp_yolov5
# Out:
# '/home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5'

# %%
sys.path.append(fp_yolov5)
sys.path
# Out:
# ['',
#  '/home/ec2-user/anaconda3/envs/pytorch_p36/lib/python36.zip',
#  '/home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6',
#  '/home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/lib-dynload',
#  '/home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages',
#  '/home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/IPython/extensions',
#  '/home/ec2-user/.ipython',
#  '/home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5']

# %% [markdown]
# ### Change working directory to yolov5

# %%
# %cd ./yolov5
# Out:
# /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5

# %% [markdown]
# # Download pre-trained models

# %%
# !python -c "from utils.google_utils import *; attempt_download('weights/yolov5s.pt');"

# %%
# !ls weights
# Out:
# download_weights.sh  yolov5s.pt

# %% [markdown]
# # Export a Trained YoloV5 Model

# %%
# !python models/export.py --weights yolov5s.pt --img 640 --batch 1

# %%
img = torch.zeros((1, 3, 640, 640))

# %%
model = torch.load('./weights/yolov5s.pt', map_location=torch.device('cpu'))['model'].float()
model.eval()
model.model[-1].export = True  # set Detect() layer export=True
y = model(img)  # dry run

# %%
fp_torchscript = './yolov5s.torchscript.pt'  # filename
ts = torch.jit.trace(model, img)
ts.save(fp_torchscript)

# %%
fp_onnx = './yolov5s.onnx'  # filename
model.fuse()  # only for ONNX
torch.onnx.export(model, img, fp_onnx, verbose=True, opset_version=12, input_names=['images'],
                          output_names=['classes', 'boxes'] if y is None else ['output'])
# Out:
# Fusing layers... Model Summary: 140 layers, 7.45958e+06 parameters, 7.45958e+06 gradients
# graph(%images : Float(1, 3, 640, 640),
#       %model.0.conv.conv.weight : Float(32, 12, 3, 3),
#       %model.0.conv.conv.bias : Float(32),
#       %model.1.conv.weight : Float(64, 32, 3, 3),
#       %model.1.conv.bias : Float(64),
#       %model.2.cv1.conv.weight : Float(32, 64, 1, 1),
#       %model.2.cv1.conv.bias : Float(32),
#       %model.2.cv2.weight : Float(32, 64, 1, 1),
#       %model.2.cv3.weight : Float(32, 32, 1, 1),
#       %model.2.cv4.conv.weight : Float(64, 64, 1, 1),
#       %model.2.cv4.conv.bias : Float(64),
#       %model.2.bn.weight : Float(64),
#       %model.2.bn.bias : Float(64),
#       %model.2.bn.running_mean : Float(64),
#       %model.2.bn.running_var : Float(64),
#       %model.2.bn.num_batches_tracked : Long(),
#       %model.2.m.0.cv1.conv.weight : Float(32, 32, 1, 1),
#       %model.2.m.0.cv1.conv.bias : Float(32),
#       %model.2.m.0.cv2.conv.weight : Float(32, 32, 3, 3),
#       %model.2.m.0.cv2.conv.bias : Float(32),
#       %model.3.conv.weight : Float(128, 64, 3, 3),
#       %model.3.conv.bias : Float(128),
#       %model.4.cv1.conv.weight : Float(64, 128, 1, 1),
#       %model.4.cv1.conv.bias : Float(64),
#       %model.4.cv2.weight : Float(64, 128, 1, 1),
#       %model.4.cv3.weight : Float(64, 64, 1, 1),
#       %model.4.cv4.conv.weight : Float(128, 128, 1, 1),
#       %model.4.cv4.conv.bias : Float(128),
#       %model.4.bn.weight : Float(128),
#       %model.4.bn.bias : Float(128),
#       %model.4.bn.running_mean : Float(128),
#       %model.4.bn.running_var : Float(128),
#       %model.4.bn.num_batches_tracked : Long(),
#       %model.4.m.0.cv1.conv.weight : Float(64, 64, 1, 1),
#       %model.4.m.0.cv1.conv.bias : Float(64),
#       %model.4.m.0.cv2.conv.weight : Float(64, 64, 3, 3),
#       %model.4.m.0.cv2.conv.bias : Float(64),
#       %model.4.m.1.cv1.conv.weight : Float(64, 64, 1, 1),
#       %model.4.m.1.cv1.conv.bias : Float(64),
#       %model.4.m.1.cv2.conv.weight : Float(64, 64, 3, 3),
#       %model.4.m.1.cv2.conv.bias : Float(64),
#       %model.4.m.2.cv1.conv.weight : Float(64, 64, 1, 1),
#       %model.4.m.2.cv1.conv.bias : Float(64),
#       %model.4.m.2.cv2.conv.weight : Float(64, 64, 3, 3),
#       %model.4.m.2.cv2.conv.bias : Float(64),
#       %model.5.conv.weight : Float(256, 128, 3, 3),
#       %model.5.conv.bias : Float(256),
#       %model.6.cv1.conv.weight : Float(128, 256, 1, 1),
#       %model.6.cv1.conv.bias : Float(128),
#       %model.6.cv2.weight : Float(128, 256, 1, 1),
#       %model.6.cv3.weight : Float(128, 128, 1, 1),
#       %model.6.cv4.conv.weight : Float(256, 256, 1, 1),
#       %model.6.cv4.conv.bias : Float(256),
#       %model.6.bn.weight : Float(256),
#       %model.6.bn.bias : Float(256),
#       %model.6.bn.running_mean : Float(256),
#       %model.6.bn.running_var : Float(256),
#       %model.6.bn.num_batches_tracked : Long(),
#       %model.6.m.0.cv1.conv.weight : Float(128, 128, 1, 1),
#       %model.6.m.0.cv1.conv.bias : Float(128),
#       %model.6.m.0.cv2.conv.weight : Float(128, 128, 3, 3),
#       %model.6.m.0.cv2.conv.bias : Float(128),
#       %model.6.m.1.cv1.conv.weight : Float(128, 128, 1, 1),
#       %model.6.m.1.cv1.conv.bias : Float(128),
#       %model.6.m.1.cv2.conv.weight : Float(128, 128, 3, 3),
#       %model.6.m.1.cv2.conv.bias : Float(128),
#       %model.6.m.2.cv1.conv.weight : Float(128, 128, 1, 1),
#       %model.6.m.2.cv1.conv.bias : Float(128),
#       %model.6.m.2.cv2.conv.weight : Float(128, 128, 3, 3),
#       %model.6.m.2.cv2.conv.bias : Float(128),
#       %model.7.conv.weight : Float(512, 256, 3, 3),
#       %model.7.conv.bias : Float(512),
#       %model.8.cv1.conv.weight : Float(256, 512, 1, 1),
#       %model.8.cv1.conv.bias : Float(256),
#       %model.8.cv2.conv.weight : Float(512, 1024, 1, 1),
#       %model.8.cv2.conv.bias : Float(512),
#       %model.9.cv1.conv.weight : Float(256, 512, 1, 1),
#       %model.9.cv1.conv.bias : Float(256),
#       %model.9.cv2.weight : Float(256, 512, 1, 1),
#       %model.9.cv3.weight : Float(256, 256, 1, 1),
#       %model.9.cv4.conv.weight : Float(512, 512, 1, 1),
#       %model.9.cv4.conv.bias : Float(512),
#       %model.9.bn.weight : Float(512),
#       %model.9.bn.bias : Float(512),
#       %model.9.bn.running_mean : Float(512),
#       %model.9.bn.running_var : Float(512),
#       %model.9.bn.num_batches_tracked : Long(),
#       %model.9.m.0.cv1.conv.weight : Float(256, 256, 1, 1),
#       %model.9.m.0.cv1.conv.bias : Float(256),
#       %model.9.m.0.cv2.conv.weight : Float(256, 256, 3, 3),
#       %model.9.m.0.cv2.conv.bias : Float(256),
#       %model.10.conv.weight : Float(256, 512, 1, 1),
#       %model.10.conv.bias : Float(256),
#       %model.13.cv1.conv.weight : Float(128, 512, 1, 1),
#       %model.13.cv1.conv.bias : Float(128),
#       %model.13.cv2.weight : Float(128, 512, 1, 1),
#       %model.13.cv3.weight : Float(128, 128, 1, 1),
#       %model.13.cv4.conv.weight : Float(256, 256, 1, 1),
#       %model.13.cv4.conv.bias : Float(256),
#       %model.13.bn.weight : Float(256),
#       %model.13.bn.bias : Float(256),
#       %model.13.bn.running_mean : Float(256),
#       %model.13.bn.running_var : Float(256),
#       %model.13.bn.num_batches_tracked : Long(),
#       %model.13.m.0.cv1.conv.weight : Float(128, 128, 1, 1),
#       %model.13.m.0.cv1.conv.bias : Float(128),
#       %model.13.m.0.cv2.conv.weight : Float(128, 128, 3, 3),
#       %model.13.m.0.cv2.conv.bias : Float(128),
#       %model.14.conv.weight : Float(128, 256, 1, 1),
#       %model.14.conv.bias : Float(128),
#       %model.17.cv1.conv.weight : Float(64, 256, 1, 1),
#       %model.17.cv1.conv.bias : Float(64),
#       %model.17.cv2.weight : Float(64, 256, 1, 1),
#       %model.17.cv3.weight : Float(64, 64, 1, 1),
#       %model.17.cv4.conv.weight : Float(128, 128, 1, 1),
#       %model.17.cv4.conv.bias : Float(128),
#       %model.17.bn.weight : Float(128),
#       %model.17.bn.bias : Float(128),
#       %model.17.bn.running_mean : Float(128),
#       %model.17.bn.running_var : Float(128),
#       %model.17.bn.num_batches_tracked : Long(),
#       %model.17.m.0.cv1.conv.weight : Float(64, 64, 1, 1),
#       %model.17.m.0.cv1.conv.bias : Float(64),
#       %model.17.m.0.cv2.conv.weight : Float(64, 64, 3, 3),
#       %model.17.m.0.cv2.conv.bias : Float(64),
#       %model.18.weight : Float(255, 128, 1, 1),
#       %model.18.bias : Float(255),
#       %model.19.conv.weight : Float(128, 128, 3, 3),
#       %model.19.conv.bias : Float(128),
#       %model.21.cv1.conv.weight : Float(128, 256, 1, 1),
#       %model.21.cv1.conv.bias : Float(128),
#       %model.21.cv2.weight : Float(128, 256, 1, 1),
#       %model.21.cv3.weight : Float(128, 128, 1, 1),
#       %model.21.cv4.conv.weight : Float(256, 256, 1, 1),
#       %model.21.cv4.conv.bias : Float(256),
#       %model.21.bn.weight : Float(256),
#       %model.21.bn.bias : Float(256),
#       %model.21.bn.running_mean : Float(256),
#       %model.21.bn.running_var : Float(256),
#       %model.21.bn.num_batches_tracked : Long(),
#       %model.21.m.0.cv1.conv.weight : Float(128, 128, 1, 1),
#       %model.21.m.0.cv1.conv.bias : Float(128),
#       %model.21.m.0.cv2.conv.weight : Float(128, 128, 3, 3),
#       %model.21.m.0.cv2.conv.bias : Float(128),
#       %model.22.weight : Float(255, 256, 1, 1),
#       %model.22.bias : Float(255),
#       %model.23.conv.weight : Float(256, 256, 3, 3),
#       %model.23.conv.bias : Float(256),
#       %model.25.cv1.conv.weight : Float(256, 512, 1, 1),
#       %model.25.cv1.conv.bias : Float(256),
#       %model.25.cv2.weight : Float(256, 512, 1, 1),
#       %model.25.cv3.weight : Float(256, 256, 1, 1),
#       %model.25.cv4.conv.weight : Float(512, 512, 1, 1),
#       %model.25.cv4.conv.bias : Float(512),
#       %model.25.bn.weight : Float(512),
#       %model.25.bn.bias : Float(512),
#       %model.25.bn.running_mean : Float(512),
#       %model.25.bn.running_var : Float(512),
#       %model.25.bn.num_batches_tracked : Long(),
#       %model.25.m.0.cv1.conv.weight : Float(256, 256, 1, 1),
#       %model.25.m.0.cv1.conv.bias : Float(256),
#       %model.25.m.0.cv2.conv.weight : Float(256, 256, 3, 3),
#       %model.25.m.0.cv2.conv.bias : Float(256),
#       %model.26.weight : Float(255, 512, 1, 1),
#       %model.26.bias : Float(255),
#       %model.27.anchors : Float(3, 3, 2),
#       %model.27.anchor_grid : Float(3, 1, 3, 1, 1, 2)):
#   %167 : Tensor = onnx::Constant[value={2}]()
#   %168 : Tensor = onnx::Constant[value={0}]()
#   %169 : Tensor = onnx::Constant[value={9223372036854775807}]()
#   %170 : Tensor = onnx::Constant[value={2}]()
#   %171 : Float(1, 3, 320, 640) = onnx::Slice(%images, %168, %169, %167, %170) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:86:0
#   %172 : Tensor = onnx::Constant[value={3}]()
#   %173 : Tensor = onnx::Constant[value={0}]()
#   %174 : Tensor = onnx::Constant[value={9223372036854775807}]()
#   %175 : Tensor = onnx::Constant[value={2}]()
#   %176 : Float(1, 3, 320, 320) = onnx::Slice(%171, %173, %174, %172, %175) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:86:0
#   %177 : Tensor = onnx::Constant[value={2}]()
#   %178 : Tensor = onnx::Constant[value={1}]()
#   %179 : Tensor = onnx::Constant[value={9223372036854775807}]()
#   %180 : Tensor = onnx::Constant[value={2}]()
#   %181 : Float(1, 3, 320, 640) = onnx::Slice(%images, %178, %179, %177, %180) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:86:0
#   %182 : Tensor = onnx::Constant[value={3}]()
#   %183 : Tensor = onnx::Constant[value={0}]()
#   %184 : Tensor = onnx::Constant[value={9223372036854775807}]()
#   %185 : Tensor = onnx::Constant[value={2}]()
#   %186 : Float(1, 3, 320, 320) = onnx::Slice(%181, %183, %184, %182, %185) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:86:0
#   %187 : Tensor = onnx::Constant[value={2}]()
#   %188 : Tensor = onnx::Constant[value={0}]()
#   %189 : Tensor = onnx::Constant[value={9223372036854775807}]()
#   %190 : Tensor = onnx::Constant[value={2}]()
#   %191 : Float(1, 3, 320, 640) = onnx::Slice(%images, %188, %189, %187, %190) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:86:0
#   %192 : Tensor = onnx::Constant[value={3}]()
#   %193 : Tensor = onnx::Constant[value={1}]()
#   %194 : Tensor = onnx::Constant[value={9223372036854775807}]()
#   %195 : Tensor = onnx::Constant[value={2}]()
#   %196 : Float(1, 3, 320, 320) = onnx::Slice(%191, %193, %194, %192, %195) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:86:0
#   %197 : Tensor = onnx::Constant[value={2}]()
#   %198 : Tensor = onnx::Constant[value={1}]()
#   %199 : Tensor = onnx::Constant[value={9223372036854775807}]()
#   %200 : Tensor = onnx::Constant[value={2}]()
#   %201 : Float(1, 3, 320, 640) = onnx::Slice(%images, %198, %199, %197, %200) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:86:0
#   %202 : Tensor = onnx::Constant[value={3}]()
#   %203 : Tensor = onnx::Constant[value={1}]()
#   %204 : Tensor = onnx::Constant[value={9223372036854775807}]()
#   %205 : Tensor = onnx::Constant[value={2}]()
#   %206 : Float(1, 3, 320, 320) = onnx::Slice(%201, %203, %204, %202, %205) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:86:0
#   %207 : Float(1, 12, 320, 320) = onnx::Concat[axis=1](%176, %186, %196, %206) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:86:0
#   %208 : Float(1, 32, 320, 320) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%207, %model.0.conv.conv.weight, %model.0.conv.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %209 : Float(1, 32, 320, 320) = onnx::LeakyRelu[alpha=0.10000000000000001](%208) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %210 : Float(1, 64, 160, 160) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%209, %model.1.conv.weight, %model.1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %211 : Float(1, 64, 160, 160) = onnx::LeakyRelu[alpha=0.10000000000000001](%210) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %212 : Float(1, 32, 160, 160) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%211, %model.2.cv1.conv.weight, %model.2.cv1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %213 : Float(1, 32, 160, 160) = onnx::LeakyRelu[alpha=0.10000000000000001](%212) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %214 : Float(1, 32, 160, 160) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%213, %model.2.m.0.cv1.conv.weight, %model.2.m.0.cv1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %215 : Float(1, 32, 160, 160) = onnx::LeakyRelu[alpha=0.10000000000000001](%214) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %216 : Float(1, 32, 160, 160) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%215, %model.2.m.0.cv2.conv.weight, %model.2.m.0.cv2.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %217 : Float(1, 32, 160, 160) = onnx::LeakyRelu[alpha=0.10000000000000001](%216) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %218 : Float(1, 32, 160, 160) = onnx::Add(%213, %217) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:43:0
#   %219 : Float(1, 32, 160, 160) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%218, %model.2.cv3.weight) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %220 : Float(1, 32, 160, 160) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%211, %model.2.cv2.weight) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %221 : Float(1, 64, 160, 160) = onnx::Concat[axis=1](%219, %220) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:62:0
#   %222 : Float(1, 64, 160, 160) = onnx::BatchNormalization[epsilon=0.001, momentum=0.98999999999999999](%221, %model.2.bn.weight, %model.2.bn.bias, %model.2.bn.running_mean, %model.2.bn.running_var) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1923:0
#   %223 : Float(1, 64, 160, 160) = onnx::LeakyRelu[alpha=0.10000000000000001](%222) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %224 : Float(1, 64, 160, 160) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%223, %model.2.cv4.conv.weight, %model.2.cv4.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %225 : Float(1, 64, 160, 160) = onnx::LeakyRelu[alpha=0.10000000000000001](%224) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %226 : Float(1, 128, 80, 80) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%225, %model.3.conv.weight, %model.3.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %227 : Float(1, 128, 80, 80) = onnx::LeakyRelu[alpha=0.10000000000000001](%226) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %228 : Float(1, 64, 80, 80) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%227, %model.4.cv1.conv.weight, %model.4.cv1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %229 : Float(1, 64, 80, 80) = onnx::LeakyRelu[alpha=0.10000000000000001](%228) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %230 : Float(1, 64, 80, 80) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%229, %model.4.m.0.cv1.conv.weight, %model.4.m.0.cv1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %231 : Float(1, 64, 80, 80) = onnx::LeakyRelu[alpha=0.10000000000000001](%230) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %232 : Float(1, 64, 80, 80) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%231, %model.4.m.0.cv2.conv.weight, %model.4.m.0.cv2.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %233 : Float(1, 64, 80, 80) = onnx::LeakyRelu[alpha=0.10000000000000001](%232) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %234 : Float(1, 64, 80, 80) = onnx::Add(%229, %233) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:43:0
#   %235 : Float(1, 64, 80, 80) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%234, %model.4.m.1.cv1.conv.weight, %model.4.m.1.cv1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %236 : Float(1, 64, 80, 80) = onnx::LeakyRelu[alpha=0.10000000000000001](%235) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %237 : Float(1, 64, 80, 80) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%236, %model.4.m.1.cv2.conv.weight, %model.4.m.1.cv2.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %238 : Float(1, 64, 80, 80) = onnx::LeakyRelu[alpha=0.10000000000000001](%237) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %239 : Float(1, 64, 80, 80) = onnx::Add(%234, %238) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:43:0
#   %240 : Float(1, 64, 80, 80) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%239, %model.4.m.2.cv1.conv.weight, %model.4.m.2.cv1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %241 : Float(1, 64, 80, 80) = onnx::LeakyRelu[alpha=0.10000000000000001](%240) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %242 : Float(1, 64, 80, 80) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%241, %model.4.m.2.cv2.conv.weight, %model.4.m.2.cv2.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %243 : Float(1, 64, 80, 80) = onnx::LeakyRelu[alpha=0.10000000000000001](%242) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %244 : Float(1, 64, 80, 80) = onnx::Add(%239, %243) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:43:0
#   %245 : Float(1, 64, 80, 80) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%244, %model.4.cv3.weight) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %246 : Float(1, 64, 80, 80) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%227, %model.4.cv2.weight) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %247 : Float(1, 128, 80, 80) = onnx::Concat[axis=1](%245, %246) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:62:0
#   %248 : Float(1, 128, 80, 80) = onnx::BatchNormalization[epsilon=0.001, momentum=0.98999999999999999](%247, %model.4.bn.weight, %model.4.bn.bias, %model.4.bn.running_mean, %model.4.bn.running_var) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1923:0
#   %249 : Float(1, 128, 80, 80) = onnx::LeakyRelu[alpha=0.10000000000000001](%248) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %250 : Float(1, 128, 80, 80) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%249, %model.4.cv4.conv.weight, %model.4.cv4.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %251 : Float(1, 128, 80, 80) = onnx::LeakyRelu[alpha=0.10000000000000001](%250) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %252 : Float(1, 256, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%251, %model.5.conv.weight, %model.5.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %253 : Float(1, 256, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%252) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %254 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%253, %model.6.cv1.conv.weight, %model.6.cv1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %255 : Float(1, 128, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%254) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %256 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%255, %model.6.m.0.cv1.conv.weight, %model.6.m.0.cv1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %257 : Float(1, 128, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%256) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %258 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%257, %model.6.m.0.cv2.conv.weight, %model.6.m.0.cv2.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %259 : Float(1, 128, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%258) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %260 : Float(1, 128, 40, 40) = onnx::Add(%255, %259) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:43:0
#   %261 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%260, %model.6.m.1.cv1.conv.weight, %model.6.m.1.cv1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %262 : Float(1, 128, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%261) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %263 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%262, %model.6.m.1.cv2.conv.weight, %model.6.m.1.cv2.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %264 : Float(1, 128, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%263) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %265 : Float(1, 128, 40, 40) = onnx::Add(%260, %264) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:43:0
#   %266 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%265, %model.6.m.2.cv1.conv.weight, %model.6.m.2.cv1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %267 : Float(1, 128, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%266) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %268 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%267, %model.6.m.2.cv2.conv.weight, %model.6.m.2.cv2.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %269 : Float(1, 128, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%268) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %270 : Float(1, 128, 40, 40) = onnx::Add(%265, %269) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:43:0
#   %271 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%270, %model.6.cv3.weight) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %272 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%253, %model.6.cv2.weight) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %273 : Float(1, 256, 40, 40) = onnx::Concat[axis=1](%271, %272) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:62:0
#   %274 : Float(1, 256, 40, 40) = onnx::BatchNormalization[epsilon=0.001, momentum=0.98999999999999999](%273, %model.6.bn.weight, %model.6.bn.bias, %model.6.bn.running_mean, %model.6.bn.running_var) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1923:0
#   %275 : Float(1, 256, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%274) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %276 : Float(1, 256, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%275, %model.6.cv4.conv.weight, %model.6.cv4.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %277 : Float(1, 256, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%276) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %278 : Float(1, 512, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%277, %model.7.conv.weight, %model.7.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %279 : Float(1, 512, 20, 20) = onnx::LeakyRelu[alpha=0.10000000000000001](%278) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %280 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%279, %model.8.cv1.conv.weight, %model.8.cv1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %281 : Float(1, 256, 20, 20) = onnx::LeakyRelu[alpha=0.10000000000000001](%280) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %282 : Float(1, 256, 20, 20) = onnx::MaxPool[ceil_mode=0, kernel_shape=[5, 5], pads=[2, 2, 2, 2], strides=[1, 1]](%281) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:539:0
#   %283 : Float(1, 256, 20, 20) = onnx::MaxPool[ceil_mode=0, kernel_shape=[9, 9], pads=[4, 4, 4, 4], strides=[1, 1]](%281) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:539:0
#   %284 : Float(1, 256, 20, 20) = onnx::MaxPool[ceil_mode=0, kernel_shape=[13, 13], pads=[6, 6, 6, 6], strides=[1, 1]](%281) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:539:0
#   %285 : Float(1, 1024, 20, 20) = onnx::Concat[axis=1](%281, %282, %283, %284) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:76:0
#   %286 : Float(1, 512, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%285, %model.8.cv2.conv.weight, %model.8.cv2.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %287 : Float(1, 512, 20, 20) = onnx::LeakyRelu[alpha=0.10000000000000001](%286) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %288 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%287, %model.9.cv1.conv.weight, %model.9.cv1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %289 : Float(1, 256, 20, 20) = onnx::LeakyRelu[alpha=0.10000000000000001](%288) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %290 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%289, %model.9.m.0.cv1.conv.weight, %model.9.m.0.cv1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %291 : Float(1, 256, 20, 20) = onnx::LeakyRelu[alpha=0.10000000000000001](%290) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %292 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%291, %model.9.m.0.cv2.conv.weight, %model.9.m.0.cv2.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %293 : Float(1, 256, 20, 20) = onnx::LeakyRelu[alpha=0.10000000000000001](%292) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %294 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%293, %model.9.cv3.weight) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %295 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%287, %model.9.cv2.weight) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %296 : Float(1, 512, 20, 20) = onnx::Concat[axis=1](%294, %295) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:62:0
#   %297 : Float(1, 512, 20, 20) = onnx::BatchNormalization[epsilon=0.001, momentum=0.98999999999999999](%296, %model.9.bn.weight, %model.9.bn.bias, %model.9.bn.running_mean, %model.9.bn.running_var) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1923:0
#   %298 : Float(1, 512, 20, 20) = onnx::LeakyRelu[alpha=0.10000000000000001](%297) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %299 : Float(1, 512, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%298, %model.9.cv4.conv.weight, %model.9.cv4.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %300 : Float(1, 512, 20, 20) = onnx::LeakyRelu[alpha=0.10000000000000001](%299) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %301 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%300, %model.10.conv.weight, %model.10.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %302 : Float(1, 256, 20, 20) = onnx::LeakyRelu[alpha=0.10000000000000001](%301) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %303 : Tensor = onnx::Shape(%302)
#   %304 : Tensor = onnx::Constant[value={2}]()
#   %305 : Long() = onnx::Gather[axis=0](%303, %304) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:2864:0
#   %306 : Float() = onnx::Cast[to=1](%305) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:2864:0
#   %307 : Float() = onnx::Constant[value={2}]()
#   %308 : Float() = onnx::Mul(%306, %307)
#   %309 : Float() = onnx::Cast[to=1](%308) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:2864:0
#   %310 : Float() = onnx::Floor(%309) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:2864:0
#   %311 : Tensor = onnx::Shape(%302)
#   %312 : Tensor = onnx::Constant[value={3}]()
#   %313 : Long() = onnx::Gather[axis=0](%311, %312) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:2864:0
#   %314 : Float() = onnx::Cast[to=1](%313) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:2864:0
#   %315 : Float() = onnx::Constant[value={2}]()
#   %316 : Float() = onnx::Mul(%314, %315)
#   %317 : Float() = onnx::Cast[to=1](%316) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:2864:0
#   %318 : Float() = onnx::Floor(%317) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:2864:0
#   %319 : Tensor = onnx::Unsqueeze[axes=[0]](%310)
#   %320 : Tensor = onnx::Unsqueeze[axes=[0]](%318)
#   %321 : Tensor = onnx::Concat[axis=0](%319, %320)
#   %322 : Tensor = onnx::Constant[value=[ CPUFloatType{0} ]]()
#   %323 : Tensor = onnx::Shape(%302)
#   %324 : Tensor = onnx::Constant[value={0}]()
#   %325 : Tensor = onnx::Constant[value={0}]()
#   %326 : Tensor = onnx::Constant[value={2}]()
#   %327 : Tensor = onnx::Slice(%323, %325, %326, %324)
#   %328 : Tensor = onnx::Cast[to=7](%321)
#   %329 : Tensor = onnx::Concat[axis=0](%327, %328)
#   %330 : Tensor = onnx::Constant[value=[ CPUFloatType{0} ]]()
#   %331 : Float(1, 256, 40, 40) = onnx::Resize[coordinate_transformation_mode="asymmetric", cubic_coeff_a=-0.75, mode="nearest", nearest_mode="floor"](%302, %322, %330, %329) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:2991:0
#   %332 : Float(1, 512, 40, 40) = onnx::Concat[axis=1](%331, %277) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:96:0
#   %333 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%332, %model.13.cv1.conv.weight, %model.13.cv1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %334 : Float(1, 128, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%333) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %335 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%334, %model.13.m.0.cv1.conv.weight, %model.13.m.0.cv1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %336 : Float(1, 128, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%335) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %337 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%336, %model.13.m.0.cv2.conv.weight, %model.13.m.0.cv2.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %338 : Float(1, 128, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%337) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %339 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%338, %model.13.cv3.weight) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %340 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%332, %model.13.cv2.weight) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %341 : Float(1, 256, 40, 40) = onnx::Concat[axis=1](%339, %340) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:62:0
#   %342 : Float(1, 256, 40, 40) = onnx::BatchNormalization[epsilon=0.001, momentum=0.98999999999999999](%341, %model.13.bn.weight, %model.13.bn.bias, %model.13.bn.running_mean, %model.13.bn.running_var) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1923:0
#   %343 : Float(1, 256, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%342) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %344 : Float(1, 256, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%343, %model.13.cv4.conv.weight, %model.13.cv4.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %345 : Float(1, 256, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%344) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %346 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%345, %model.14.conv.weight, %model.14.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %347 : Float(1, 128, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%346) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %348 : Tensor = onnx::Shape(%347)
#   %349 : Tensor = onnx::Constant[value={2}]()
#   %350 : Long() = onnx::Gather[axis=0](%348, %349) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:2864:0
#   %351 : Float() = onnx::Cast[to=1](%350) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:2864:0
#   %352 : Float() = onnx::Constant[value={2}]()
#   %353 : Float() = onnx::Mul(%351, %352)
#   %354 : Float() = onnx::Cast[to=1](%353) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:2864:0
#   %355 : Float() = onnx::Floor(%354) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:2864:0
#   %356 : Tensor = onnx::Shape(%347)
#   %357 : Tensor = onnx::Constant[value={3}]()
#   %358 : Long() = onnx::Gather[axis=0](%356, %357) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:2864:0
#   %359 : Float() = onnx::Cast[to=1](%358) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:2864:0
#   %360 : Float() = onnx::Constant[value={2}]()
#   %361 : Float() = onnx::Mul(%359, %360)
#   %362 : Float() = onnx::Cast[to=1](%361) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:2864:0
#   %363 : Float() = onnx::Floor(%362) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:2864:0
#   %364 : Tensor = onnx::Unsqueeze[axes=[0]](%355)
#   %365 : Tensor = onnx::Unsqueeze[axes=[0]](%363)
#   %366 : Tensor = onnx::Concat[axis=0](%364, %365)
#   %367 : Tensor = onnx::Constant[value=[ CPUFloatType{0} ]]()
#   %368 : Tensor = onnx::Shape(%347)
#   %369 : Tensor = onnx::Constant[value={0}]()
#   %370 : Tensor = onnx::Constant[value={0}]()
#   %371 : Tensor = onnx::Constant[value={2}]()
#   %372 : Tensor = onnx::Slice(%368, %370, %371, %369)
#   %373 : Tensor = onnx::Cast[to=7](%366)
#   %374 : Tensor = onnx::Concat[axis=0](%372, %373)
#   %375 : Tensor = onnx::Constant[value=[ CPUFloatType{0} ]]()
#   %376 : Float(1, 128, 80, 80) = onnx::Resize[coordinate_transformation_mode="asymmetric", cubic_coeff_a=-0.75, mode="nearest", nearest_mode="floor"](%347, %367, %375, %374) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:2991:0
#   %377 : Float(1, 256, 80, 80) = onnx::Concat[axis=1](%376, %251) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:96:0
#   %378 : Float(1, 64, 80, 80) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%377, %model.17.cv1.conv.weight, %model.17.cv1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %379 : Float(1, 64, 80, 80) = onnx::LeakyRelu[alpha=0.10000000000000001](%378) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %380 : Float(1, 64, 80, 80) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%379, %model.17.m.0.cv1.conv.weight, %model.17.m.0.cv1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %381 : Float(1, 64, 80, 80) = onnx::LeakyRelu[alpha=0.10000000000000001](%380) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %382 : Float(1, 64, 80, 80) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%381, %model.17.m.0.cv2.conv.weight, %model.17.m.0.cv2.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %383 : Float(1, 64, 80, 80) = onnx::LeakyRelu[alpha=0.10000000000000001](%382) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %384 : Float(1, 64, 80, 80) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%383, %model.17.cv3.weight) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %385 : Float(1, 64, 80, 80) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%377, %model.17.cv2.weight) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %386 : Float(1, 128, 80, 80) = onnx::Concat[axis=1](%384, %385) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:62:0
#   %387 : Float(1, 128, 80, 80) = onnx::BatchNormalization[epsilon=0.001, momentum=0.98999999999999999](%386, %model.17.bn.weight, %model.17.bn.bias, %model.17.bn.running_mean, %model.17.bn.running_var) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1923:0
#   %388 : Float(1, 128, 80, 80) = onnx::LeakyRelu[alpha=0.10000000000000001](%387) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %389 : Float(1, 128, 80, 80) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%388, %model.17.cv4.conv.weight, %model.17.cv4.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %390 : Float(1, 128, 80, 80) = onnx::LeakyRelu[alpha=0.10000000000000001](%389) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %391 : Float(1, 255, 80, 80) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%390, %model.18.weight, %model.18.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %392 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%390, %model.19.conv.weight, %model.19.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %393 : Float(1, 128, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%392) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %394 : Float(1, 256, 40, 40) = onnx::Concat[axis=1](%393, %347) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:96:0
#   %395 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%394, %model.21.cv1.conv.weight, %model.21.cv1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %396 : Float(1, 128, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%395) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %397 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%396, %model.21.m.0.cv1.conv.weight, %model.21.m.0.cv1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %398 : Float(1, 128, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%397) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %399 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%398, %model.21.m.0.cv2.conv.weight, %model.21.m.0.cv2.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %400 : Float(1, 128, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%399) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %401 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%400, %model.21.cv3.weight) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %402 : Float(1, 128, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%394, %model.21.cv2.weight) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %403 : Float(1, 256, 40, 40) = onnx::Concat[axis=1](%401, %402) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:62:0
#   %404 : Float(1, 256, 40, 40) = onnx::BatchNormalization[epsilon=0.001, momentum=0.98999999999999999](%403, %model.21.bn.weight, %model.21.bn.bias, %model.21.bn.running_mean, %model.21.bn.running_var) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1923:0
#   %405 : Float(1, 256, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%404) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %406 : Float(1, 256, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%405, %model.21.cv4.conv.weight, %model.21.cv4.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %407 : Float(1, 256, 40, 40) = onnx::LeakyRelu[alpha=0.10000000000000001](%406) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %408 : Float(1, 255, 40, 40) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%407, %model.22.weight, %model.22.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %409 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%407, %model.23.conv.weight, %model.23.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %410 : Float(1, 256, 20, 20) = onnx::LeakyRelu[alpha=0.10000000000000001](%409) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %411 : Float(1, 512, 20, 20) = onnx::Concat[axis=1](%410, %302) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:96:0
#   %412 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%411, %model.25.cv1.conv.weight, %model.25.cv1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %413 : Float(1, 256, 20, 20) = onnx::LeakyRelu[alpha=0.10000000000000001](%412) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %414 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%413, %model.25.m.0.cv1.conv.weight, %model.25.m.0.cv1.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %415 : Float(1, 256, 20, 20) = onnx::LeakyRelu[alpha=0.10000000000000001](%414) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %416 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%415, %model.25.m.0.cv2.conv.weight, %model.25.m.0.cv2.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %417 : Float(1, 256, 20, 20) = onnx::LeakyRelu[alpha=0.10000000000000001](%416) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %418 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%417, %model.25.cv3.weight) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %419 : Float(1, 256, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%411, %model.25.cv2.weight) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %420 : Float(1, 512, 20, 20) = onnx::Concat[axis=1](%418, %419) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/common.py:62:0
#   %421 : Float(1, 512, 20, 20) = onnx::BatchNormalization[epsilon=0.001, momentum=0.98999999999999999](%420, %model.25.bn.weight, %model.25.bn.bias, %model.25.bn.running_mean, %model.25.bn.running_var) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1923:0
#   %422 : Float(1, 512, 20, 20) = onnx::LeakyRelu[alpha=0.10000000000000001](%421) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %423 : Float(1, 512, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%422, %model.25.cv4.conv.weight, %model.25.cv4.conv.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %424 : Float(1, 512, 20, 20) = onnx::LeakyRelu[alpha=0.10000000000000001](%423) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/functional.py:1237:0
#   %425 : Float(1, 255, 20, 20) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%424, %model.26.weight, %model.26.bias) # /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/nn/modules/conv.py:350:0
#   %426 : Tensor = onnx::Shape(%425)
#   %427 : Tensor = onnx::Constant[value={0}]()
#   %428 : Long() = onnx::Gather[axis=0](%426, %427) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/yolo.py:26:0
#   %429 : Tensor = onnx::Shape(%425)
#   %430 : Tensor = onnx::Constant[value={2}]()
#   %431 : Long() = onnx::Gather[axis=0](%429, %430) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/yolo.py:26:0
#   %432 : Tensor = onnx::Shape(%425)
#   %433 : Tensor = onnx::Constant[value={3}]()
#   %434 : Long() = onnx::Gather[axis=0](%432, %433) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/yolo.py:26:0
#   %435 : Long() = onnx::Constant[value={3}]()
#   %436 : Long() = onnx::Constant[value={85}]()
#   %437 : Tensor = onnx::Unsqueeze[axes=[0]](%428)
#   %438 : Tensor = onnx::Unsqueeze[axes=[0]](%435)
#   %439 : Tensor = onnx::Unsqueeze[axes=[0]](%436)
#   %440 : Tensor = onnx::Unsqueeze[axes=[0]](%431)
#   %441 : Tensor = onnx::Unsqueeze[axes=[0]](%434)
#   %442 : Tensor = onnx::Concat[axis=0](%437, %438, %439, %440, %441)
#   %443 : Float(1, 3, 85, 20, 20) = onnx::Reshape(%425, %442) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/yolo.py:27:0
#   %output : Float(1, 3, 20, 20, 85) = onnx::Transpose[perm=[0, 1, 3, 4, 2]](%443) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/yolo.py:27:0
#   %445 : Tensor = onnx::Shape(%408)
#   %446 : Tensor = onnx::Constant[value={0}]()
#   %447 : Long() = onnx::Gather[axis=0](%445, %446) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/yolo.py:26:0
#   %448 : Tensor = onnx::Shape(%408)
#   %449 : Tensor = onnx::Constant[value={2}]()
#   %450 : Long() = onnx::Gather[axis=0](%448, %449) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/yolo.py:26:0
#   %451 : Tensor = onnx::Shape(%408)
#   %452 : Tensor = onnx::Constant[value={3}]()
#   %453 : Long() = onnx::Gather[axis=0](%451, %452) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/yolo.py:26:0
#   %454 : Long() = onnx::Constant[value={3}]()
#   %455 : Long() = onnx::Constant[value={85}]()
#   %456 : Tensor = onnx::Unsqueeze[axes=[0]](%447)
#   %457 : Tensor = onnx::Unsqueeze[axes=[0]](%454)
#   %458 : Tensor = onnx::Unsqueeze[axes=[0]](%455)
#   %459 : Tensor = onnx::Unsqueeze[axes=[0]](%450)
#   %460 : Tensor = onnx::Unsqueeze[axes=[0]](%453)
#   %461 : Tensor = onnx::Concat[axis=0](%456, %457, %458, %459, %460)
#   %462 : Float(1, 3, 85, 40, 40) = onnx::Reshape(%408, %461) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/yolo.py:27:0
#   %463 : Float(1, 3, 40, 40, 85) = onnx::Transpose[perm=[0, 1, 3, 4, 2]](%462) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/yolo.py:27:0
#   %464 : Tensor = onnx::Shape(%391)
#   %465 : Tensor = onnx::Constant[value={0}]()
#   %466 : Long() = onnx::Gather[axis=0](%464, %465) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/yolo.py:26:0
#   %467 : Tensor = onnx::Shape(%391)
#   %468 : Tensor = onnx::Constant[value={2}]()
#   %469 : Long() = onnx::Gather[axis=0](%467, %468) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/yolo.py:26:0
#   %470 : Tensor = onnx::Shape(%391)
#   %471 : Tensor = onnx::Constant[value={3}]()
#   %472 : Long() = onnx::Gather[axis=0](%470, %471) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/yolo.py:26:0
#   %473 : Long() = onnx::Constant[value={3}]()
#   %474 : Long() = onnx::Constant[value={85}]()
#   %475 : Tensor = onnx::Unsqueeze[axes=[0]](%466)
#   %476 : Tensor = onnx::Unsqueeze[axes=[0]](%473)
#   %477 : Tensor = onnx::Unsqueeze[axes=[0]](%474)
#   %478 : Tensor = onnx::Unsqueeze[axes=[0]](%469)
#   %479 : Tensor = onnx::Unsqueeze[axes=[0]](%472)
#   %480 : Tensor = onnx::Concat[axis=0](%475, %476, %477, %478, %479)
#   %481 : Float(1, 3, 85, 80, 80) = onnx::Reshape(%391, %480) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/yolo.py:27:0
#   %482 : Float(1, 3, 80, 80, 85) = onnx::Transpose[perm=[0, 1, 3, 4, 2]](%481) # /home/ec2-user/SageMaker/myAWSStudyBlog/sagemaker-greengrass/0-yolov5-onnx/yolov5/models/yolo.py:27:0
#   return (%output, %463, %482)

# %%
onnx_model = onnx.load(fp_onnx)  # load onnx model
onnx.checker.check_model(onnx_model)  # check onnx model
print(onnx.helper.printable_graph(onnx_model.graph))  # print a human readable model
print('ONNX export success, saved as %s' % fp_onnx)
# Out:
# graph torch-jit-export (
#   %images[FLOAT, 1x3x640x640]
# ) initializers (
#   %model.0.conv.conv.bias[FLOAT, 32]
#   %model.0.conv.conv.weight[FLOAT, 32x12x3x3]
#   %model.1.conv.bias[FLOAT, 64]
#   %model.1.conv.weight[FLOAT, 64x32x3x3]
#   %model.10.conv.bias[FLOAT, 256]
#   %model.10.conv.weight[FLOAT, 256x512x1x1]
#   %model.13.bn.bias[FLOAT, 256]
#   %model.13.bn.num_batches_tracked[INT64, scalar]
#   %model.13.bn.running_mean[FLOAT, 256]
#   %model.13.bn.running_var[FLOAT, 256]
#   %model.13.bn.weight[FLOAT, 256]
#   %model.13.cv1.conv.bias[FLOAT, 128]
#   %model.13.cv1.conv.weight[FLOAT, 128x512x1x1]
#   %model.13.cv2.weight[FLOAT, 128x512x1x1]
#   %model.13.cv3.weight[FLOAT, 128x128x1x1]
#   %model.13.cv4.conv.bias[FLOAT, 256]
#   %model.13.cv4.conv.weight[FLOAT, 256x256x1x1]
#   %model.13.m.0.cv1.conv.bias[FLOAT, 128]
#   %model.13.m.0.cv1.conv.weight[FLOAT, 128x128x1x1]
#   %model.13.m.0.cv2.conv.bias[FLOAT, 128]
#   %model.13.m.0.cv2.conv.weight[FLOAT, 128x128x3x3]
#   %model.14.conv.bias[FLOAT, 128]
#   %model.14.conv.weight[FLOAT, 128x256x1x1]
#   %model.17.bn.bias[FLOAT, 128]
#   %model.17.bn.num_batches_tracked[INT64, scalar]
#   %model.17.bn.running_mean[FLOAT, 128]
#   %model.17.bn.running_var[FLOAT, 128]
#   %model.17.bn.weight[FLOAT, 128]
#   %model.17.cv1.conv.bias[FLOAT, 64]
#   %model.17.cv1.conv.weight[FLOAT, 64x256x1x1]
#   %model.17.cv2.weight[FLOAT, 64x256x1x1]
#   %model.17.cv3.weight[FLOAT, 64x64x1x1]
#   %model.17.cv4.conv.bias[FLOAT, 128]
#   %model.17.cv4.conv.weight[FLOAT, 128x128x1x1]
#   %model.17.m.0.cv1.conv.bias[FLOAT, 64]
#   %model.17.m.0.cv1.conv.weight[FLOAT, 64x64x1x1]
#   %model.17.m.0.cv2.conv.bias[FLOAT, 64]
#   %model.17.m.0.cv2.conv.weight[FLOAT, 64x64x3x3]
#   %model.18.bias[FLOAT, 255]
#   %model.18.weight[FLOAT, 255x128x1x1]
#   %model.19.conv.bias[FLOAT, 128]
#   %model.19.conv.weight[FLOAT, 128x128x3x3]
#   %model.2.bn.bias[FLOAT, 64]
#   %model.2.bn.num_batches_tracked[INT64, scalar]
#   %model.2.bn.running_mean[FLOAT, 64]
#   %model.2.bn.running_var[FLOAT, 64]
#   %model.2.bn.weight[FLOAT, 64]
#   %model.2.cv1.conv.bias[FLOAT, 32]
#   %model.2.cv1.conv.weight[FLOAT, 32x64x1x1]
#   %model.2.cv2.weight[FLOAT, 32x64x1x1]
#   %model.2.cv3.weight[FLOAT, 32x32x1x1]
#   %model.2.cv4.conv.bias[FLOAT, 64]
#   %model.2.cv4.conv.weight[FLOAT, 64x64x1x1]
#   %model.2.m.0.cv1.conv.bias[FLOAT, 32]
#   %model.2.m.0.cv1.conv.weight[FLOAT, 32x32x1x1]
#   %model.2.m.0.cv2.conv.bias[FLOAT, 32]
#   %model.2.m.0.cv2.conv.weight[FLOAT, 32x32x3x3]
#   %model.21.bn.bias[FLOAT, 256]
#   %model.21.bn.num_batches_tracked[INT64, scalar]
#   %model.21.bn.running_mean[FLOAT, 256]
#   %model.21.bn.running_var[FLOAT, 256]
#   %model.21.bn.weight[FLOAT, 256]
#   %model.21.cv1.conv.bias[FLOAT, 128]
#   %model.21.cv1.conv.weight[FLOAT, 128x256x1x1]
#   %model.21.cv2.weight[FLOAT, 128x256x1x1]
#   %model.21.cv3.weight[FLOAT, 128x128x1x1]
#   %model.21.cv4.conv.bias[FLOAT, 256]
#   %model.21.cv4.conv.weight[FLOAT, 256x256x1x1]
#   %model.21.m.0.cv1.conv.bias[FLOAT, 128]
#   %model.21.m.0.cv1.conv.weight[FLOAT, 128x128x1x1]
#   %model.21.m.0.cv2.conv.bias[FLOAT, 128]
#   %model.21.m.0.cv2.conv.weight[FLOAT, 128x128x3x3]
#   %model.22.bias[FLOAT, 255]
#   %model.22.weight[FLOAT, 255x256x1x1]
#   %model.23.conv.bias[FLOAT, 256]
#   %model.23.conv.weight[FLOAT, 256x256x3x3]
#   %model.25.bn.bias[FLOAT, 512]
#   %model.25.bn.num_batches_tracked[INT64, scalar]
#   %model.25.bn.running_mean[FLOAT, 512]
#   %model.25.bn.running_var[FLOAT, 512]
#   %model.25.bn.weight[FLOAT, 512]
#   %model.25.cv1.conv.bias[FLOAT, 256]
#   %model.25.cv1.conv.weight[FLOAT, 256x512x1x1]
#   %model.25.cv2.weight[FLOAT, 256x512x1x1]
#   %model.25.cv3.weight[FLOAT, 256x256x1x1]
#   %model.25.cv4.conv.bias[FLOAT, 512]
#   %model.25.cv4.conv.weight[FLOAT, 512x512x1x1]
#   %model.25.m.0.cv1.conv.bias[FLOAT, 256]
#   %model.25.m.0.cv1.conv.weight[FLOAT, 256x256x1x1]
#   %model.25.m.0.cv2.conv.bias[FLOAT, 256]
#   %model.25.m.0.cv2.conv.weight[FLOAT, 256x256x3x3]
#   %model.26.bias[FLOAT, 255]
#   %model.26.weight[FLOAT, 255x512x1x1]
#   %model.27.anchor_grid[FLOAT, 3x1x3x1x1x2]
#   %model.27.anchors[FLOAT, 3x3x2]
#   %model.3.conv.bias[FLOAT, 128]
#   %model.3.conv.weight[FLOAT, 128x64x3x3]
#   %model.4.bn.bias[FLOAT, 128]
#   %model.4.bn.num_batches_tracked[INT64, scalar]
#   %model.4.bn.running_mean[FLOAT, 128]
#   %model.4.bn.running_var[FLOAT, 128]
#   %model.4.bn.weight[FLOAT, 128]
#   %model.4.cv1.conv.bias[FLOAT, 64]
#   %model.4.cv1.conv.weight[FLOAT, 64x128x1x1]
#   %model.4.cv2.weight[FLOAT, 64x128x1x1]
#   %model.4.cv3.weight[FLOAT, 64x64x1x1]
#   %model.4.cv4.conv.bias[FLOAT, 128]
#   %model.4.cv4.conv.weight[FLOAT, 128x128x1x1]
#   %model.4.m.0.cv1.conv.bias[FLOAT, 64]
#   %model.4.m.0.cv1.conv.weight[FLOAT, 64x64x1x1]
#   %model.4.m.0.cv2.conv.bias[FLOAT, 64]
#   %model.4.m.0.cv2.conv.weight[FLOAT, 64x64x3x3]
#   %model.4.m.1.cv1.conv.bias[FLOAT, 64]
#   %model.4.m.1.cv1.conv.weight[FLOAT, 64x64x1x1]
#   %model.4.m.1.cv2.conv.bias[FLOAT, 64]
#   %model.4.m.1.cv2.conv.weight[FLOAT, 64x64x3x3]
#   %model.4.m.2.cv1.conv.bias[FLOAT, 64]
#   %model.4.m.2.cv1.conv.weight[FLOAT, 64x64x1x1]
#   %model.4.m.2.cv2.conv.bias[FLOAT, 64]
#   %model.4.m.2.cv2.conv.weight[FLOAT, 64x64x3x3]
#   %model.5.conv.bias[FLOAT, 256]
#   %model.5.conv.weight[FLOAT, 256x128x3x3]
#   %model.6.bn.bias[FLOAT, 256]
#   %model.6.bn.num_batches_tracked[INT64, scalar]
#   %model.6.bn.running_mean[FLOAT, 256]
#   %model.6.bn.running_var[FLOAT, 256]
#   %model.6.bn.weight[FLOAT, 256]
#   %model.6.cv1.conv.bias[FLOAT, 128]
#   %model.6.cv1.conv.weight[FLOAT, 128x256x1x1]
#   %model.6.cv2.weight[FLOAT, 128x256x1x1]
#   %model.6.cv3.weight[FLOAT, 128x128x1x1]
#   %model.6.cv4.conv.bias[FLOAT, 256]
#   %model.6.cv4.conv.weight[FLOAT, 256x256x1x1]
#   %model.6.m.0.cv1.conv.bias[FLOAT, 128]
#   %model.6.m.0.cv1.conv.weight[FLOAT, 128x128x1x1]
#   %model.6.m.0.cv2.conv.bias[FLOAT, 128]
#   %model.6.m.0.cv2.conv.weight[FLOAT, 128x128x3x3]
#   %model.6.m.1.cv1.conv.bias[FLOAT, 128]
#   %model.6.m.1.cv1.conv.weight[FLOAT, 128x128x1x1]
#   %model.6.m.1.cv2.conv.bias[FLOAT, 128]
#   %model.6.m.1.cv2.conv.weight[FLOAT, 128x128x3x3]
#   %model.6.m.2.cv1.conv.bias[FLOAT, 128]
#   %model.6.m.2.cv1.conv.weight[FLOAT, 128x128x1x1]
#   %model.6.m.2.cv2.conv.bias[FLOAT, 128]
#   %model.6.m.2.cv2.conv.weight[FLOAT, 128x128x3x3]
#   %model.7.conv.bias[FLOAT, 512]
#   %model.7.conv.weight[FLOAT, 512x256x3x3]
#   %model.8.cv1.conv.bias[FLOAT, 256]
#   %model.8.cv1.conv.weight[FLOAT, 256x512x1x1]
#   %model.8.cv2.conv.bias[FLOAT, 512]
#   %model.8.cv2.conv.weight[FLOAT, 512x1024x1x1]
#   %model.9.bn.bias[FLOAT, 512]
#   %model.9.bn.num_batches_tracked[INT64, scalar]
#   %model.9.bn.running_mean[FLOAT, 512]
#   %model.9.bn.running_var[FLOAT, 512]
#   %model.9.bn.weight[FLOAT, 512]
#   %model.9.cv1.conv.bias[FLOAT, 256]
#   %model.9.cv1.conv.weight[FLOAT, 256x512x1x1]
#   %model.9.cv2.weight[FLOAT, 256x512x1x1]
#   %model.9.cv3.weight[FLOAT, 256x256x1x1]
#   %model.9.cv4.conv.bias[FLOAT, 512]
#   %model.9.cv4.conv.weight[FLOAT, 512x512x1x1]
#   %model.9.m.0.cv1.conv.bias[FLOAT, 256]
#   %model.9.m.0.cv1.conv.weight[FLOAT, 256x256x1x1]
#   %model.9.m.0.cv2.conv.bias[FLOAT, 256]
#   %model.9.m.0.cv2.conv.weight[FLOAT, 256x256x3x3]
# ) {
#   %167 = Constant[value = <Tensor>]()
#   %168 = Constant[value = <Tensor>]()
#   %169 = Constant[value = <Tensor>]()
#   %170 = Constant[value = <Tensor>]()
#   %171 = Slice(%images, %168, %169, %167, %170)
#   %172 = Constant[value = <Tensor>]()
#   %173 = Constant[value = <Tensor>]()
#   %174 = Constant[value = <Tensor>]()
#   %175 = Constant[value = <Tensor>]()
#   %176 = Slice(%171, %173, %174, %172, %175)
#   %177 = Constant[value = <Tensor>]()
#   %178 = Constant[value = <Tensor>]()
#   %179 = Constant[value = <Tensor>]()
#   %180 = Constant[value = <Tensor>]()
#   %181 = Slice(%images, %178, %179, %177, %180)
#   %182 = Constant[value = <Tensor>]()
#   %183 = Constant[value = <Tensor>]()
#   %184 = Constant[value = <Tensor>]()
#   %185 = Constant[value = <Tensor>]()
#   %186 = Slice(%181, %183, %184, %182, %185)
#   %187 = Constant[value = <Tensor>]()
#   %188 = Constant[value = <Tensor>]()
#   %189 = Constant[value = <Tensor>]()
#   %190 = Constant[value = <Tensor>]()
#   %191 = Slice(%images, %188, %189, %187, %190)
#   %192 = Constant[value = <Tensor>]()
#   %193 = Constant[value = <Tensor>]()
#   %194 = Constant[value = <Tensor>]()
#   %195 = Constant[value = <Tensor>]()
#   %196 = Slice(%191, %193, %194, %192, %195)
#   %197 = Constant[value = <Tensor>]()
#   %198 = Constant[value = <Tensor>]()
#   %199 = Constant[value = <Tensor>]()
#   %200 = Constant[value = <Tensor>]()
#   %201 = Slice(%images, %198, %199, %197, %200)
#   %202 = Constant[value = <Tensor>]()
#   %203 = Constant[value = <Tensor>]()
#   %204 = Constant[value = <Tensor>]()
#   %205 = Constant[value = <Tensor>]()
#   %206 = Slice(%201, %203, %204, %202, %205)
#   %207 = Concat[axis = 1](%176, %186, %196, %206)
#   %208 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%207, %model.0.conv.conv.weight, %model.0.conv.conv.bias)
#   %209 = LeakyRelu[alpha = 0.100000001490116](%208)
#   %210 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%209, %model.1.conv.weight, %model.1.conv.bias)
#   %211 = LeakyRelu[alpha = 0.100000001490116](%210)
#   %212 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%211, %model.2.cv1.conv.weight, %model.2.cv1.conv.bias)
#   %213 = LeakyRelu[alpha = 0.100000001490116](%212)
#   %214 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%213, %model.2.m.0.cv1.conv.weight, %model.2.m.0.cv1.conv.bias)
#   %215 = LeakyRelu[alpha = 0.100000001490116](%214)
#   %216 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%215, %model.2.m.0.cv2.conv.weight, %model.2.m.0.cv2.conv.bias)
#   %217 = LeakyRelu[alpha = 0.100000001490116](%216)
#   %218 = Add(%213, %217)
#   %219 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%218, %model.2.cv3.weight)
#   %220 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%211, %model.2.cv2.weight)
#   %221 = Concat[axis = 1](%219, %220)
#   %222 = BatchNormalization[epsilon = 0.00100000004749745, momentum = 0.990000009536743](%221, %model.2.bn.weight, %model.2.bn.bias, %model.2.bn.running_mean, %model.2.bn.running_var)
#   %223 = LeakyRelu[alpha = 0.100000001490116](%222)
#   %224 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%223, %model.2.cv4.conv.weight, %model.2.cv4.conv.bias)
#   %225 = LeakyRelu[alpha = 0.100000001490116](%224)
#   %226 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%225, %model.3.conv.weight, %model.3.conv.bias)
#   %227 = LeakyRelu[alpha = 0.100000001490116](%226)
#   %228 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%227, %model.4.cv1.conv.weight, %model.4.cv1.conv.bias)
#   %229 = LeakyRelu[alpha = 0.100000001490116](%228)
#   %230 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%229, %model.4.m.0.cv1.conv.weight, %model.4.m.0.cv1.conv.bias)
#   %231 = LeakyRelu[alpha = 0.100000001490116](%230)
#   %232 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%231, %model.4.m.0.cv2.conv.weight, %model.4.m.0.cv2.conv.bias)
#   %233 = LeakyRelu[alpha = 0.100000001490116](%232)
#   %234 = Add(%229, %233)
#   %235 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%234, %model.4.m.1.cv1.conv.weight, %model.4.m.1.cv1.conv.bias)
#   %236 = LeakyRelu[alpha = 0.100000001490116](%235)
#   %237 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%236, %model.4.m.1.cv2.conv.weight, %model.4.m.1.cv2.conv.bias)
#   %238 = LeakyRelu[alpha = 0.100000001490116](%237)
#   %239 = Add(%234, %238)
#   %240 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%239, %model.4.m.2.cv1.conv.weight, %model.4.m.2.cv1.conv.bias)
#   %241 = LeakyRelu[alpha = 0.100000001490116](%240)
#   %242 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%241, %model.4.m.2.cv2.conv.weight, %model.4.m.2.cv2.conv.bias)
#   %243 = LeakyRelu[alpha = 0.100000001490116](%242)
#   %244 = Add(%239, %243)
#   %245 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%244, %model.4.cv3.weight)
#   %246 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%227, %model.4.cv2.weight)
#   %247 = Concat[axis = 1](%245, %246)
#   %248 = BatchNormalization[epsilon = 0.00100000004749745, momentum = 0.990000009536743](%247, %model.4.bn.weight, %model.4.bn.bias, %model.4.bn.running_mean, %model.4.bn.running_var)
#   %249 = LeakyRelu[alpha = 0.100000001490116](%248)
#   %250 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%249, %model.4.cv4.conv.weight, %model.4.cv4.conv.bias)
#   %251 = LeakyRelu[alpha = 0.100000001490116](%250)
#   %252 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%251, %model.5.conv.weight, %model.5.conv.bias)
#   %253 = LeakyRelu[alpha = 0.100000001490116](%252)
#   %254 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%253, %model.6.cv1.conv.weight, %model.6.cv1.conv.bias)
#   %255 = LeakyRelu[alpha = 0.100000001490116](%254)
#   %256 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%255, %model.6.m.0.cv1.conv.weight, %model.6.m.0.cv1.conv.bias)
#   %257 = LeakyRelu[alpha = 0.100000001490116](%256)
#   %258 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%257, %model.6.m.0.cv2.conv.weight, %model.6.m.0.cv2.conv.bias)
#   %259 = LeakyRelu[alpha = 0.100000001490116](%258)
#   %260 = Add(%255, %259)
#   %261 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%260, %model.6.m.1.cv1.conv.weight, %model.6.m.1.cv1.conv.bias)
#   %262 = LeakyRelu[alpha = 0.100000001490116](%261)
#   %263 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%262, %model.6.m.1.cv2.conv.weight, %model.6.m.1.cv2.conv.bias)
#   %264 = LeakyRelu[alpha = 0.100000001490116](%263)
#   %265 = Add(%260, %264)
#   %266 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%265, %model.6.m.2.cv1.conv.weight, %model.6.m.2.cv1.conv.bias)
#   %267 = LeakyRelu[alpha = 0.100000001490116](%266)
#   %268 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%267, %model.6.m.2.cv2.conv.weight, %model.6.m.2.cv2.conv.bias)
#   %269 = LeakyRelu[alpha = 0.100000001490116](%268)
#   %270 = Add(%265, %269)
#   %271 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%270, %model.6.cv3.weight)
#   %272 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%253, %model.6.cv2.weight)
#   %273 = Concat[axis = 1](%271, %272)
#   %274 = BatchNormalization[epsilon = 0.00100000004749745, momentum = 0.990000009536743](%273, %model.6.bn.weight, %model.6.bn.bias, %model.6.bn.running_mean, %model.6.bn.running_var)
#   %275 = LeakyRelu[alpha = 0.100000001490116](%274)
#   %276 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%275, %model.6.cv4.conv.weight, %model.6.cv4.conv.bias)
#   %277 = LeakyRelu[alpha = 0.100000001490116](%276)
#   %278 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%277, %model.7.conv.weight, %model.7.conv.bias)
#   %279 = LeakyRelu[alpha = 0.100000001490116](%278)
#   %280 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%279, %model.8.cv1.conv.weight, %model.8.cv1.conv.bias)
#   %281 = LeakyRelu[alpha = 0.100000001490116](%280)
#   %282 = MaxPool[ceil_mode = 0, kernel_shape = [5, 5], pads = [2, 2, 2, 2], strides = [1, 1]](%281)
#   %283 = MaxPool[ceil_mode = 0, kernel_shape = [9, 9], pads = [4, 4, 4, 4], strides = [1, 1]](%281)
#   %284 = MaxPool[ceil_mode = 0, kernel_shape = [13, 13], pads = [6, 6, 6, 6], strides = [1, 1]](%281)
#   %285 = Concat[axis = 1](%281, %282, %283, %284)
#   %286 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%285, %model.8.cv2.conv.weight, %model.8.cv2.conv.bias)
#   %287 = LeakyRelu[alpha = 0.100000001490116](%286)
#   %288 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%287, %model.9.cv1.conv.weight, %model.9.cv1.conv.bias)
#   %289 = LeakyRelu[alpha = 0.100000001490116](%288)
#   %290 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%289, %model.9.m.0.cv1.conv.weight, %model.9.m.0.cv1.conv.bias)
#   %291 = LeakyRelu[alpha = 0.100000001490116](%290)
#   %292 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%291, %model.9.m.0.cv2.conv.weight, %model.9.m.0.cv2.conv.bias)
#   %293 = LeakyRelu[alpha = 0.100000001490116](%292)
#   %294 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%293, %model.9.cv3.weight)
#   %295 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%287, %model.9.cv2.weight)
#   %296 = Concat[axis = 1](%294, %295)
#   %297 = BatchNormalization[epsilon = 0.00100000004749745, momentum = 0.990000009536743](%296, %model.9.bn.weight, %model.9.bn.bias, %model.9.bn.running_mean, %model.9.bn.running_var)
#   %298 = LeakyRelu[alpha = 0.100000001490116](%297)
#   %299 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%298, %model.9.cv4.conv.weight, %model.9.cv4.conv.bias)
#   %300 = LeakyRelu[alpha = 0.100000001490116](%299)
#   %301 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%300, %model.10.conv.weight, %model.10.conv.bias)
#   %302 = LeakyRelu[alpha = 0.100000001490116](%301)
#   %303 = Shape(%302)
#   %304 = Constant[value = <Scalar Tensor []>]()
#   %305 = Gather[axis = 0](%303, %304)
#   %306 = Cast[to = 1](%305)
#   %307 = Constant[value = <Scalar Tensor []>]()
#   %308 = Mul(%306, %307)
#   %309 = Cast[to = 1](%308)
#   %310 = Floor(%309)
#   %311 = Shape(%302)
#   %312 = Constant[value = <Scalar Tensor []>]()
#   %313 = Gather[axis = 0](%311, %312)
#   %314 = Cast[to = 1](%313)
#   %315 = Constant[value = <Scalar Tensor []>]()
#   %316 = Mul(%314, %315)
#   %317 = Cast[to = 1](%316)
#   %318 = Floor(%317)
#   %319 = Unsqueeze[axes = [0]](%310)
#   %320 = Unsqueeze[axes = [0]](%318)
#   %321 = Concat[axis = 0](%319, %320)
#   %322 = Constant[value = <Tensor>]()
#   %323 = Shape(%302)
#   %324 = Constant[value = <Tensor>]()
#   %325 = Constant[value = <Tensor>]()
#   %326 = Constant[value = <Tensor>]()
#   %327 = Slice(%323, %325, %326, %324)
#   %328 = Cast[to = 7](%321)
#   %329 = Concat[axis = 0](%327, %328)
#   %330 = Constant[value = <Tensor>]()
#   %331 = Resize[coordinate_transformation_mode = 'asymmetric', cubic_coeff_a = -0.75, mode = 'nearest', nearest_mode = 'floor'](%302, %322, %330, %329)
#   %332 = Concat[axis = 1](%331, %277)
#   %333 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%332, %model.13.cv1.conv.weight, %model.13.cv1.conv.bias)
#   %334 = LeakyRelu[alpha = 0.100000001490116](%333)
#   %335 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%334, %model.13.m.0.cv1.conv.weight, %model.13.m.0.cv1.conv.bias)
#   %336 = LeakyRelu[alpha = 0.100000001490116](%335)
#   %337 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%336, %model.13.m.0.cv2.conv.weight, %model.13.m.0.cv2.conv.bias)
#   %338 = LeakyRelu[alpha = 0.100000001490116](%337)
#   %339 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%338, %model.13.cv3.weight)
#   %340 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%332, %model.13.cv2.weight)
#   %341 = Concat[axis = 1](%339, %340)
#   %342 = BatchNormalization[epsilon = 0.00100000004749745, momentum = 0.990000009536743](%341, %model.13.bn.weight, %model.13.bn.bias, %model.13.bn.running_mean, %model.13.bn.running_var)
#   %343 = LeakyRelu[alpha = 0.100000001490116](%342)
#   %344 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%343, %model.13.cv4.conv.weight, %model.13.cv4.conv.bias)
#   %345 = LeakyRelu[alpha = 0.100000001490116](%344)
#   %346 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%345, %model.14.conv.weight, %model.14.conv.bias)
#   %347 = LeakyRelu[alpha = 0.100000001490116](%346)
#   %348 = Shape(%347)
#   %349 = Constant[value = <Scalar Tensor []>]()
#   %350 = Gather[axis = 0](%348, %349)
#   %351 = Cast[to = 1](%350)
#   %352 = Constant[value = <Scalar Tensor []>]()
#   %353 = Mul(%351, %352)
#   %354 = Cast[to = 1](%353)
#   %355 = Floor(%354)
#   %356 = Shape(%347)
#   %357 = Constant[value = <Scalar Tensor []>]()
#   %358 = Gather[axis = 0](%356, %357)
#   %359 = Cast[to = 1](%358)
#   %360 = Constant[value = <Scalar Tensor []>]()
#   %361 = Mul(%359, %360)
#   %362 = Cast[to = 1](%361)
#   %363 = Floor(%362)
#   %364 = Unsqueeze[axes = [0]](%355)
#   %365 = Unsqueeze[axes = [0]](%363)
#   %366 = Concat[axis = 0](%364, %365)
#   %367 = Constant[value = <Tensor>]()
#   %368 = Shape(%347)
#   %369 = Constant[value = <Tensor>]()
#   %370 = Constant[value = <Tensor>]()
#   %371 = Constant[value = <Tensor>]()
#   %372 = Slice(%368, %370, %371, %369)
#   %373 = Cast[to = 7](%366)
#   %374 = Concat[axis = 0](%372, %373)
#   %375 = Constant[value = <Tensor>]()
#   %376 = Resize[coordinate_transformation_mode = 'asymmetric', cubic_coeff_a = -0.75, mode = 'nearest', nearest_mode = 'floor'](%347, %367, %375, %374)
#   %377 = Concat[axis = 1](%376, %251)
#   %378 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%377, %model.17.cv1.conv.weight, %model.17.cv1.conv.bias)
#   %379 = LeakyRelu[alpha = 0.100000001490116](%378)
#   %380 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%379, %model.17.m.0.cv1.conv.weight, %model.17.m.0.cv1.conv.bias)
#   %381 = LeakyRelu[alpha = 0.100000001490116](%380)
#   %382 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%381, %model.17.m.0.cv2.conv.weight, %model.17.m.0.cv2.conv.bias)
#   %383 = LeakyRelu[alpha = 0.100000001490116](%382)
#   %384 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%383, %model.17.cv3.weight)
#   %385 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%377, %model.17.cv2.weight)
#   %386 = Concat[axis = 1](%384, %385)
#   %387 = BatchNormalization[epsilon = 0.00100000004749745, momentum = 0.990000009536743](%386, %model.17.bn.weight, %model.17.bn.bias, %model.17.bn.running_mean, %model.17.bn.running_var)
#   %388 = LeakyRelu[alpha = 0.100000001490116](%387)
#   %389 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%388, %model.17.cv4.conv.weight, %model.17.cv4.conv.bias)
#   %390 = LeakyRelu[alpha = 0.100000001490116](%389)
#   %391 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%390, %model.18.weight, %model.18.bias)
#   %392 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%390, %model.19.conv.weight, %model.19.conv.bias)
#   %393 = LeakyRelu[alpha = 0.100000001490116](%392)
#   %394 = Concat[axis = 1](%393, %347)
#   %395 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%394, %model.21.cv1.conv.weight, %model.21.cv1.conv.bias)
#   %396 = LeakyRelu[alpha = 0.100000001490116](%395)
#   %397 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%396, %model.21.m.0.cv1.conv.weight, %model.21.m.0.cv1.conv.bias)
#   %398 = LeakyRelu[alpha = 0.100000001490116](%397)
#   %399 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%398, %model.21.m.0.cv2.conv.weight, %model.21.m.0.cv2.conv.bias)
#   %400 = LeakyRelu[alpha = 0.100000001490116](%399)
#   %401 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%400, %model.21.cv3.weight)
#   %402 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%394, %model.21.cv2.weight)
#   %403 = Concat[axis = 1](%401, %402)
#   %404 = BatchNormalization[epsilon = 0.00100000004749745, momentum = 0.990000009536743](%403, %model.21.bn.weight, %model.21.bn.bias, %model.21.bn.running_mean, %model.21.bn.running_var)
#   %405 = LeakyRelu[alpha = 0.100000001490116](%404)
#   %406 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%405, %model.21.cv4.conv.weight, %model.21.cv4.conv.bias)
#   %407 = LeakyRelu[alpha = 0.100000001490116](%406)
#   %408 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%407, %model.22.weight, %model.22.bias)
#   %409 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [2, 2]](%407, %model.23.conv.weight, %model.23.conv.bias)
#   %410 = LeakyRelu[alpha = 0.100000001490116](%409)
#   %411 = Concat[axis = 1](%410, %302)
#   %412 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%411, %model.25.cv1.conv.weight, %model.25.cv1.conv.bias)
#   %413 = LeakyRelu[alpha = 0.100000001490116](%412)
#   %414 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%413, %model.25.m.0.cv1.conv.weight, %model.25.m.0.cv1.conv.bias)
#   %415 = LeakyRelu[alpha = 0.100000001490116](%414)
#   %416 = Conv[dilations = [1, 1], group = 1, kernel_shape = [3, 3], pads = [1, 1, 1, 1], strides = [1, 1]](%415, %model.25.m.0.cv2.conv.weight, %model.25.m.0.cv2.conv.bias)
#   %417 = LeakyRelu[alpha = 0.100000001490116](%416)
#   %418 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%417, %model.25.cv3.weight)
#   %419 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%411, %model.25.cv2.weight)
#   %420 = Concat[axis = 1](%418, %419)
#   %421 = BatchNormalization[epsilon = 0.00100000004749745, momentum = 0.990000009536743](%420, %model.25.bn.weight, %model.25.bn.bias, %model.25.bn.running_mean, %model.25.bn.running_var)
#   %422 = LeakyRelu[alpha = 0.100000001490116](%421)
#   %423 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%422, %model.25.cv4.conv.weight, %model.25.cv4.conv.bias)
#   %424 = LeakyRelu[alpha = 0.100000001490116](%423)
#   %425 = Conv[dilations = [1, 1], group = 1, kernel_shape = [1, 1], pads = [0, 0, 0, 0], strides = [1, 1]](%424, %model.26.weight, %model.26.bias)
#   %426 = Shape(%425)
#   %427 = Constant[value = <Scalar Tensor []>]()
#   %428 = Gather[axis = 0](%426, %427)
#   %429 = Shape(%425)
#   %430 = Constant[value = <Scalar Tensor []>]()
#   %431 = Gather[axis = 0](%429, %430)
#   %432 = Shape(%425)
#   %433 = Constant[value = <Scalar Tensor []>]()
#   %434 = Gather[axis = 0](%432, %433)
#   %435 = Constant[value = <Scalar Tensor []>]()
#   %436 = Constant[value = <Scalar Tensor []>]()
#   %437 = Unsqueeze[axes = [0]](%428)
#   %438 = Unsqueeze[axes = [0]](%435)
#   %439 = Unsqueeze[axes = [0]](%436)
#   %440 = Unsqueeze[axes = [0]](%431)
#   %441 = Unsqueeze[axes = [0]](%434)
#   %442 = Concat[axis = 0](%437, %438, %439, %440, %441)
#   %443 = Reshape(%425, %442)
#   %output = Transpose[perm = [0, 1, 3, 4, 2]](%443)
#   %445 = Shape(%408)
#   %446 = Constant[value = <Scalar Tensor []>]()
#   %447 = Gather[axis = 0](%445, %446)
#   %448 = Shape(%408)
#   %449 = Constant[value = <Scalar Tensor []>]()
#   %450 = Gather[axis = 0](%448, %449)
#   %451 = Shape(%408)
#   %452 = Constant[value = <Scalar Tensor []>]()
#   %453 = Gather[axis = 0](%451, %452)
#   %454 = Constant[value = <Scalar Tensor []>]()
#   %455 = Constant[value = <Scalar Tensor []>]()
#   %456 = Unsqueeze[axes = [0]](%447)
#   %457 = Unsqueeze[axes = [0]](%454)
#   %458 = Unsqueeze[axes = [0]](%455)
#   %459 = Unsqueeze[axes = [0]](%450)
#   %460 = Unsqueeze[axes = [0]](%453)
#   %461 = Concat[axis = 0](%456, %457, %458, %459, %460)
#   %462 = Reshape(%408, %461)
#   %463 = Transpose[perm = [0, 1, 3, 4, 2]](%462)
#   %464 = Shape(%391)
#   %465 = Constant[value = <Scalar Tensor []>]()
#   %466 = Gather[axis = 0](%464, %465)
#   %467 = Shape(%391)
#   %468 = Constant[value = <Scalar Tensor []>]()
#   %469 = Gather[axis = 0](%467, %468)
#   %470 = Shape(%391)
#   %471 = Constant[value = <Scalar Tensor []>]()
#   %472 = Gather[axis = 0](%470, %471)
#   %473 = Constant[value = <Scalar Tensor []>]()
#   %474 = Constant[value = <Scalar Tensor []>]()
#   %475 = Unsqueeze[axes = [0]](%466)
#   %476 = Unsqueeze[axes = [0]](%473)
#   %477 = Unsqueeze[axes = [0]](%474)
#   %478 = Unsqueeze[axes = [0]](%469)
#   %479 = Unsqueeze[axes = [0]](%472)
#   %480 = Concat[axis = 0](%475, %476, %477, %478, %479)
#   %481 = Reshape(%391, %480)
#   %482 = Transpose[perm = [0, 1, 3, 4, 2]](%481)
#   return %output, %463, %482
# }
# ONNX export success, saved as ./yolov5s.onnx

# %% [markdown]
# ### Move tourch script and ONNX model out

# %%
# !cp {fp_torchscript} ../yolov5s.torchscript.pt
# !cp {fp_onnx} ../yolov5s.onnx
