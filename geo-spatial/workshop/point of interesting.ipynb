# %%
import pandas as pd
import awswrangler

# %%
fp = './data/DE.txt'

# %%
df = pd.read_csv(fp,sep='\t',header=None)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#         0                 1                 2   \
# 0  1529666   Bahnhof Grenzau   Bahnhof Grenzau
# 1  2038682  Bahnhof Annaburg  Bahnhof Annaburg
# 2  2658739     Schiener Bach     Schiener Bach
# 3  2659829        Lunkenbach        Lunkenbach
# 4  2744273        Witte Venn        Witte Venn
#
#                                        3         4         5  6     7   8   \
# 0                         Bahnhof Grenzau  50.45715   7.66512  S  RSTN  DE
# 1  Bahnhof Annaburg,Bahnhof Annaburg West  51.72833  13.33361  S  RSTN  DE
# 2                           Schiener Bach  47.68020   8.86131  H   STM  DE
# 3                  Lunckenbach,Lunkenbach  47.68136   8.84938  H   STM  DE
# 4                   Witte Veen,Witte Venn  52.15000   6.88333  H  MRSH  DE
#
#       9     10   11      12         13  14  15   16                17  \
# 0    NaN   8.0  0.0  7143.0  7143032.0   0 NaN  231     Europe/Berlin
# 1    NaN  11.0  NaN     NaN        NaN   0 NaN   84     Europe/Berlin
# ...
