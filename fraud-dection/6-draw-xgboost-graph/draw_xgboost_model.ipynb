# %%
# !pip install xgboost==0.90 graphviz
# Out:
# Requirement already satisfied: xgboost==0.90 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (0.90)
# Requirement already satisfied: graphviz in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (0.13.2)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from xgboost==0.90) (1.14.3)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from xgboost==0.90) (1.1.0)
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import boto3
sm = boto3.client('sagemaker')

# %%
job_name = 'sagemaker-xgboost-200317-1526-013-10e63509'
respone = sm.describe_training_job(TrainingJobName=job_name)
model_url = respone['ModelArtifacts']['S3ModelArtifacts']
model_url
# Out:
# 's3://beyoung-fraud-detection-20200317/xgboost-balanced-data/output/sagemaker-xgboost-200317-1526-013-10e63509/output/model.tar.gz'

# %%
# !aws s3 cp {model_url} ./model.tar.gz
# Out:
# download: s3://beyoung-fraud-detection-20200317/xgboost-balanced-data/output/sagemaker-xgboost-200317-1526-013-10e63509/output/model.tar.gz to ./model.tar.gz

# %%
# !tar -xvf ./model.tar.gz
# Out:
# xgboost-model

# %%
import pickle
import xgboost as xgb
import numpy as np
transaction= "-1.009630,0.141192,0.167167,-0.808785,2.112167,-1.294934,0.592454,-0.049872,-0.284882,-1.296757,-1.010293,-0.272631,-0.139809,-0.918097,-0.475136,0.519497,0.158822,-0.120745,-0.519128,0.108956,-0.225473,-0.947079,0.054725,0.368866,-0.158482,0.070904,0.022035,0.177674,-0.279746,0.391123"
test = transaction.split(',')
data = np.asarray(test).reshape((1,-1))
test_matrix = xgb.DMatrix(data)
filename = "./xgboost-model"
xgb_loaded = pickle.load(open(filename, 'rb'))
predictions = xgb_loaded.predict(test_matrix)
predictions[0]
# Out:
# 0.06256128

# %%
from xgboost import plot_tree, Booster
import xgboost as xgb
import matplotlib.pyplot as plt
import pickle as pkl
from xgboost import plot_tree, plot_importance
from matplotlib.pylab import rcParams

filename='./xgboost-model'
# plot single tree
rcParams['figure.figsize'] = 50,50
 
model = pkl.load(open(filename,'rb')) 
plot_tree(model, num_trees=4)
plt.show()
